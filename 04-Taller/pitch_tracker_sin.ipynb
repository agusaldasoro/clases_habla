# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from __future__ import division
from IPython.display import Audio, Image
import matplotlib.pyplot as plt
import pitch
import midi
import wav
import signal_processing
import visualizations

from pylab import rcParams
rcParams['figure.figsize'] = 16, 5
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sample_rate = 44100
freq = 400

sinu_signal = signal_processing.sin(sampleRate = sample_rate, duration = 0.5, freq = freq)
filename = wav.save_as_wav(sinu_signal, sample_rate)

visualizations.wave(0, 0.02, sample_rate, sinu_signal)

T = (1/freq)
print("T", T)
print("T (samples)", int(T * sample_rate))

print("freq", freq)
print("sample_rate", sample_rate)
print("length signal", len(sinu_signal))

pitch_step = 0.001 

pitch_times, pitch_points = pitch.track(signal=sinu_signal, step=pitch_step, sample_rate=sample_rate, method=pitch.freq_from_zcr)
visualizations.pitch_track(sinu_signal, pitch_times, pitch_points, 0, 1000)

Audio(filename)
# Out:
# ('T', 0.0025)
# ('T (samples)', 110)
# ('freq', 400)
# ('sample_rate', 44100)
# ('length signal', 22050)
# ('Time: ', 0, ', Pitch: ', 400.90909090909093)
# ('Time: ', 44, ', Pitch: ', 400.90909090909093)
# ('Time: ', 88, ', Pitch: ', 400.90909090909093)
# ('Time: ', 132, ', Pitch: ', 400.90909090909093)
# ('Time: ', 176, ', Pitch: ', 400.90909090909093)
# ('Time: ', 220, ', Pitch: ', 400.90909090909093)
# ('Time: ', 264, ', Pitch: ', 397.2972972972973)
# ('Time: ', 308, ', Pitch: ', 397.2972972972973)
# ('Time: ', 352, ', Pitch: ', 400.90909090909093)
# ('Time: ', 396, ', Pitch: ', 400.90909090909093)
# ('Time: ', 440, ', Pitch: ', 400.90909090909093)
# ('Time: ', 484, ', Pitch: ', 400.90909090909093)
# ('Time: ', 528, ', Pitch: ', 400.90909090909093)
# ('Time: ', 572, ', Pitch: ', 400.90909090909093)
# ('Time: ', 616, ', Pitch: ', 400.90909090909093)
# ('Time: ', 660, ', Pitch: ', 400.90909090909093)
# ('Time: ', 704, ', Pitch: ', 397.2972972972973)
# ('Time: ', 748, ', Pitch: ', 397.2972972972973)
# ('Time: ', 792, ', Pitch: ', 400.90909090909093)
# ('Time: ', 836, ', Pitch: ', 400.90909090909093)
# ('Time: ', 880, ', Pitch: ', 400.90909090909093)
# ('Time: ', 924, ', Pitch: ', 400.90909090909093)
# ('Time: ', 968, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1012, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1056, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1100, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1144, ', Pitch: ', 397.2972972972973)
# ('Time: ', 1188, ', Pitch: ', 397.2972972972973)
# ('Time: ', 1232, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1276, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1320, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1364, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1408, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1452, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1496, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1540, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1584, ', Pitch: ', 397.2972972972973)
# ('Time: ', 1628, ', Pitch: ', 397.2972972972973)
# ('Time: ', 1672, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1716, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1760, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1804, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1848, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1892, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1936, ', Pitch: ', 400.90909090909093)
# ('Time: ', 1980, ', Pitch: ', 400.90909090909093)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-41047652c444> in <module>()
#      17 pitch_step = 0.001
#      18
# ---> 19 pitch_times, pitch_points = pitch.track(signal=sinu_signal, step=pitch_step, sample_rate=sample_rate, method=pitch.freq_from_zcr)
#      20 visualizations.pitch_track(sinu_signal, pitch_times, pitch_points, 0, 1000)
#      21
#
# /home/ph-02/Documentos/clases_habla/04-Taller/pitch.py in track(signal, step, sample_rate, method)
#      62             # signal[index:][:minimum_sample]
#      63             intervalo = signal_processing.data_between(t0, 0.05, signal, sample_rate)
# ---> 64             pitch = method(intervalo, sample_rate)
#      65             pitch_track.append(pitch)
#      66             print("Time: ", index, ", Pitch: ", pitch)
#
# /home/ph-02/Documentos/clases_habla/04-Taller/pitch.py in freq_from_zcr(signal, sample_rate)
#      43             zeros.append(i)
#      44         i += 1
# ---> 45     periodo = (zeros[1]-zeros[0])/sample_rate
#      46     return 1/periodo
#      47
#
# IndexError: list index out of range
